# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://traveltriangle.com/tour-packages/kerala"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
pagecontent = response.text

# %%
soup = BeautifulSoup(pagecontent)

# %%
name = soup.find("span",attrs={"class":"fw9 m0 f16 pfc3"})
name
# Out:
# <span class="fw9 m0 f16 pfc3">Alleppey-Munnar Kerala Weekend Tour </span>

# %%
names = []

for x in soup.find_all("span",attrs={"class":"fw9 m0 f16 pfc3"}):
    names.append(x.text.strip() if x else np.nan)

for name in names:
    print(name)
# Out:
# Alleppey-Munnar Kerala Weekend Tour
# Charismatic Kochi Tour Package
# Hills & Houseboat: Munnar and Alleppey Honeymoon Package
# Vibrant Kochi Munnar Honeymoon Tour Package
# Mesmerizing Getaway To Kochi
# Kerala Wayanad Weekend Holiday
# Trip To Mesmerising Munnar
# Best Selling Kerala Honeymoon Tour Package
# Catch The Beauty Of The Setting Sun In Alleppey
# Best Selling Kerala Houseboat & Jungle Safari Tour Package
# Charming Alleppey Honeymoon Package
# A Blissful Tour In Munnar
# Top 5 Nights 6 Days Kerala Family Tour Packages For A Refreshing Getaway
# Exploring Godâs Own Country, Kerala
# Reasonable Munnar Thekkady Alleppey Honeymoon Packages
# Ecstatic Athirapally Tour Package
# Mesmerizing Kerala Holiday: Weekend in Munnar & Thekkady
# Captivating Thekkady Honeymoon Package
# A Surreal Escape To Mesmerising Destinations
# Visit Kerala And See Astounding Places

# %%
dp = soup.find("span",attrs = {"class":"f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label"})
dp
# Out:
# <span class="f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label">24<!-- -->% Off</span>

# %%
dp = []

for x in soup.find_all("span",attrs={"class":"f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label"}):
    dp.append(x.text.strip() if x else np.nan)

for name in dp:
    print(name)
# Out:
# 24% Off
# 9% Off
# 10% Off
# 10% Off
# 9% Off
# 5% Off
# 9% Off
# 28% Off
# 9% Off
# 19% Off
# 9% Off
# 9% Off
# 18% Off
# 10% Off
# 12% Off
# 9% Off
# 29% Off
# 10% Off
# 21% Off
# 11% Off

# %%
cities = soup.find("ul",attrs = {"class":"clearfix package-cities-list at_packagecity_list"})
cities
# Out:
# <ul class="clearfix package-cities-list at_packagecity_list"><li class="f12">Munnar<!-- --> (2D)</li><li class="f12">Alleppey<!-- --> (2D)</li></ul>

# %%
cities = []

for x in soup.find_all("ul",attrs={"class":"clearfix package-cities-list at_packagecity_list"}):
    cities.append(x.text.strip() if x else np.nan)

for name in cities:
    print(name)
# Out:
# Munnar (2D)Alleppey (2D)
# Kochi (1D)Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Cochin (1D)Munnar (3D)
# Kochi (2D)
# Wayanad (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (2D)
# Munnar (2D)Thekkady (1D)Alleppey (2D)
# Alleppey (3D)
# Munnar (3D)
# Munnar (2D)Thekkady (1D)Alleppey (1D)Kochi (2D)
# Munnar (1D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Alleppey (2D)
# Athirapally (2D)Munnar (2D)Alleppey (1D)Kovalam (1D)Trivandrum (2D)
# Munnar (2D)Thekkady (2D)
# Kumarakom (1D)Thekkady (1D)Munnar (3D)
# Munnar (2D)Alleppey (2D)
# Munnar (1D)Thekkady (1D)Kochi (2D)

# %%
for i in range(1,62):
    url = f"https://traveltriangle.com/tour-packages/Kerala/page/{i}"
    print(url)
# Out:
# https://traveltriangle.com/tour-packages/Kerala/page/1
# https://traveltriangle.com/tour-packages/Kerala/page/2
# https://traveltriangle.com/tour-packages/Kerala/page/3
# https://traveltriangle.com/tour-packages/Kerala/page/4
# https://traveltriangle.com/tour-packages/Kerala/page/5
# https://traveltriangle.com/tour-packages/Kerala/page/6
# https://traveltriangle.com/tour-packages/Kerala/page/7
# https://traveltriangle.com/tour-packages/Kerala/page/8
# https://traveltriangle.com/tour-packages/Kerala/page/9
# https://traveltriangle.com/tour-packages/Kerala/page/10
# https://traveltriangle.com/tour-packages/Kerala/page/11
# https://traveltriangle.com/tour-packages/Kerala/page/12
# https://traveltriangle.com/tour-packages/Kerala/page/13
# https://traveltriangle.com/tour-packages/Kerala/page/14
# https://traveltriangle.com/tour-packages/Kerala/page/15
# https://traveltriangle.com/tour-packages/Kerala/page/16
# https://traveltriangle.com/tour-packages/Kerala/page/17
# ...

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

Name = [] 

stay = []

location = []

discount = []

pagenum = []

Packages = []

Price = []
total_time = time.time()
for i in range(1, 62): 

    start_time = time.time()

    URL = f"https://traveltriangle.com/tour-packages/kerala?travelmonth=May%2C%202026={i}"

    page = requests.get(URL)

    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'col-12 p8 pt0'}):

        name_tag = x.find('p', attrs={"class":"col-md-12 pl0 fw9 m0 f16 pfc3 at_packageName"})

        stay_tag = x.find('span', attrs={'class':'iblock sfc6'})   # discounted price

        location_tag = x.find('ul', attrs={'class':'clearfix package-cities-list at_packagecity_list'})

        discount_tag = x.find('span', attrs={'class':'f12 fw4 pt2 pb2 pl8 pr8 radius20 pbc1 sfcw at_discount_label'})

        Price_tag = x.find('p', attrs={'class':'sfc3 m0 f20 fw9 priceVal at_newprice'})

        Tags_tag = x.find('ul',attrs={'class':'package-tags at_package_tags'})

        Name.append(name_tag.text.strip() if name_tag else np.nan)

        stay.append(stay_tag.text.strip() if stay_tag else np.nan)

        location.append(location_tag.text.strip() if location_tag else np.nan)

        discount.append(discount_tag.text.strip() if discount_tag else np.nan)

        Price.append(Price_tag.text.strip() if Price_tag else np.nan)

        Packages.append(Tags_tag.text.strip() if Tags_tag else np.nan)

        pagenum.append(i)
 
    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 2.43 seconds
# Page 2 completed in 1.87 seconds
# Page 3 completed in 1.97 seconds
# Page 4 completed in 2.97 seconds
# Page 5 completed in 1.85 seconds
# Page 6 completed in 5.24 seconds
# Page 7 completed in 1.85 seconds
# Page 8 completed in 1.83 seconds
# Page 9 completed in 2.06 seconds
# Page 10 completed in 1.86 seconds
# Page 11 completed in 1.88 seconds
# Page 12 completed in 1.90 seconds
# Page 13 completed in 1.79 seconds
# Page 14 completed in 2.01 seconds
# Page 15 completed in 1.94 seconds
# Page 16 completed in 1.79 seconds
# Page 17 completed in 1.75 seconds
# Page 18 completed in 1.76 seconds
# Page 19 completed in 1.94 seconds
# Page 20 completed in 1.96 seconds
# Page 21 completed in 1.82 seconds
# Page 22 completed in 1.78 seconds
# Page 23 completed in 1.99 seconds
# Page 24 completed in 1.86 seconds
# Page 25 completed in 1.91 seconds
# Page 26 completed in 1.86 seconds
# Page 27 completed in 1.88 seconds
# Page 28 completed in 2.25 seconds
# ...

# %%
df = pd.DataFrame({
    "Name": Name,
    "Stay": stay,
    "Location": location,
    "Discount": discount,
    "Price": Price,
    "Packages": Packages,
    "Page Number": pagenum})

# %%
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location Discount  \
# ...

# %%
df.to_csv("travel.csv",index = False)

# %%
df = pd.read_csv("travel.csv")
df
# Out:
#                                                    Name               Stay  \
# 0                   Alleppey-Munnar Kerala Weekend Tour  4 Days & 3 Nights
# 1                        Charismatic Kochi Tour Package  4 Days & 3 Nights
# 2     Hills & Houseboat: Munnar and Alleppey Honeymo...  6 Days & 5 Nights
# 3           Vibrant Kochi Munnar Honeymoon Tour Package  4 Days & 3 Nights
# 4                          Mesmerizing Getaway To Kochi  2 Days & 1 Nights
# ...                                                 ...                ...
# 1215                  Ecstatic Athirapally Tour Package  8 Days & 7 Nights
# 1216  Mesmerizing Kerala Holiday: Weekend in Munnar ...  4 Days & 3 Nights
# 1217             Captivating Thekkady Honeymoon Package  5 Days & 4 Nights
# 1218       A Surreal Escape To Mesmerising Destinations  4 Days & 3 Nights
# 1219             Visit Kerala And See Astounding Places  4 Days & 3 Nights
#
#                                                Location Discount  \
# ...
